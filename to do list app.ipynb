# %%
# Define a dictionary to store tasks
tasks = {}

# Function to add a task
def add_task():
    task_name = input("Enter task name: ")
    task_priority = input("Enter task priority (high, medium, low): ")
    tasks[task_name] = task_priority
    print("Task added successfully!")

# Function to delete a task
def delete_task():
    task_name = input("Enter the task name to delete: ")
    if task_name in tasks:
        del tasks[task_name]
        print("Task deleted successfully!")
    else:
        print("Task not found.")

# Function to display all tasks
def display_tasks():
    if tasks:
        print("Tasks:")
        for task, priority in tasks.items():
            print(f"{task} - Priority: {priority}")
    else:
        print("No tasks to display.")

# Main function to run the program
def main():
    while True:
        print("\n*** To-Do List App ***")
        print("1. Add Task")
        print("2. Delete Task")
        print("3. Display Tasks")
        print("4. Exit")

        choice = input("Enter your choice: ")

        if choice == '1':
            add_task()
        elif choice == '2':
            delete_task()
        elif choice == '3':
            display_tasks()
        elif choice == '4':
            print("Exiting...")
            break
        else:
            print("Invalid choice. Please try again.")

if __name__ == "__main__":
    main()
# Out:
# *** To-Do List App ***
# 1. Add Task
# 2. Delete Task
# 3. Display Tasks
# 4. Exit
# Enter your choice: 1
# Enter task name: golu khana kahyega
# Enter task priority (high, medium, low): khana
# Task added successfully!
#
# *** To-Do List App ***
# 1. Add Task
# 2. Delete Task
# 3. Display Tasks
# 4. Exit
# Enter your choice: 1.
# Invalid choice. Please try again.
#
# *** To-Do List App ***
# 1. Add Task
# 2. Delete Task
# 3. Display Tasks
# 4. Exit
# Enter your choice: Golu royega
# Invalid choice. Please try again.
#
# *** To-Do List App ***
# 1. Add Task
# 2. Delete Task
# 3. Display Tasks
# 4. Exit
# Enter your choice: 1
# Enter task name: golu royega
# Enter task priority (high, medium, low): royega
# Task added successfully!
#
# *** To-Do List App ***
# 1. Add Task
# 2. Delete Task
# 3. Display Tasks
# 4. Exit
# Enter your choice: 2
# Enter the task name to delete: 2
# Task not found.
#
# *** To-Do List App ***
# 1. Add Task
# 2. Delete Task
# 3. Display Tasks
# 4. Exit
# Enter your choice: 3
# Tasks:
# golu khana kahyega  - Priority: khana
# golu royega  - Priority: royega
#
# *** To-Do List App ***
# 1. Add Task
# 2. Delete Task
# 3. Display Tasks
# 4. Exit
